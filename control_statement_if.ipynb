# %% [markdown]
# # if문의 기본 구조
#
# if문의 기본은 if와 else로 이루어져 있다.
#
# 조건문을 테스트한 후, True면 if문 바로 다음 문장(if 블록)을 수행하고, False면 else문 바로 다음 문장(else 블록)을 수행한다.
#
# if문에서 if는 단독으로 사용될 수 있지만, else는 단독으로 사용될 수 없다.

# %%
a = 1
b = 3

if a > b:
    print("a가 b보다 큽니다.")
else:
    print("a가 b보다 크지 않습니다.")
# Out:
# a가 b보다 크지 않습니다.

# %%
# 기본 구조
# if 조건문:
#     수행할 문장 1
#     수행할 문장 2
#     ...
# else:
#     수행할 문장 1
#     수행할 문장 2
#     ...

# %%
a = 3
b = 1

if a > b:
    print("a가 b보다 큽니다.")

print("if문 다음 실행")
# Out:
# a가 b보다 큽니다.
# if문 다음 실행

# %%
a = 1
b = 3

if a > b:
    print("a가 b보다 큽니다.")

print("if문 다음 실행")
# Out:
# if문 다음 실행

# %%
a = 1
b = 3

else:
    print("a가 b보다 큽니다.")

print("if문 다음 실행")
# Out:
#   Cell In[4], line 4
#     else:
#     ^
# SyntaxError: invalid syntax

# %% [markdown]
# ## 들여쓰기 (Indentation)
#
# 파이썬에서 들여쓰기는 중요한 요소이다. 같은 들여쓰기를 가지고 있는 문장들은 하나의 블록으로 여겨지기 때문이다.
#
# if문에서도 if 조건문: 다음으로 쓰이는 모든 문장은 들여쓰기가 필수이다. 만약 들여쓰기가 되어있지 않는다면, 이는 if 조건문: 블록 안에 들어있는 것이 아닌 문장으로 취급된다.
#
# 또한, 들여쓰기가 잘못된 경우엔 에러를 발생하기도 한다.
#
# 다른 프로그래밍 언어에서는 하나의 블록은 중괄호 등을 사용해서 묶어주는 경우가 많다.
#
# 그렇기 때문에 다른 프로그래밍 언어를 공부해본 사람들은 들여쓰기를 꼭 맞춰야 한다는 점이 어색할 수도 있어서 주의가 필요하다.

# %%
a = 1
b = 3

if a > b:
    print("들여쓰기가 다르다면?!")
print("a가 b보다 큽니다.")
# Out:
# a가 b보다 큽니다.

# %%
a = 1
b = 3

if a > b:
    print("들여쓰기가 다르다면?!")
print("a가 b보다 큽니다.")
    print("이럴 때는?!")
# Out:
#   Cell In[5], line 7
#     print("이럴 때는?!")
#     ^
# IndentationError: unexpected indent

# %%
# 올바른 결과 출력
# 조건이 맞지 않기 때문에 출력이 아무것도 없다.
a = 1
b = 3

if a > b:
    print("들여쓰기가 다르다면?!")
    print("a가 b보다 큽니다.")

# %% [markdown]
# # 조건문이란 무엇인가?
#
# if 조건문:에서 조건문은 참(True)과 거짓(False)을 판단하는 문장을 의미한다.

# %% [markdown]
# ## 비교연산자
#
# 비교연산자는 이름 그대로 두 값을 비교해서 불(Bool, Boolean) 자료형으로 결과 값을 반환해주는 연산자이다.
#
# 크다(>), 작다(<), 크거나 같다(>=), 작거나 같다(<=), 같다(==), 같지 않다(!=) 등이 있다.

# %%
x = 3
y = 5

print(x > y)
print(x < y)
# Out:
# False
# True

# %%
x = 3
y = 5

print(x >= y)
print(x <= y)
# Out:
# False
# True

# %%
x = 3
y = 3

print(x >= y)
print(x <= y)
# Out:
# True
# True

# %%
x = 3
y = 5

print(x == y)
print(x != y)
# Out:
# False
# True

# %% [markdown]
# ## 논리연산자
#
# 논리연산자는 불 자료형에서 불 연산자로 쓰인 것과 같다.
#
# and, or, not 연산자가 있다.

# %%
x = 1
y = 3
z = 5

print((x > y) and (x > z)) # False and False
print((x < y) and (x < z)) # True and True
print((x < y) and (x > z)) # False and True
# Out:
# False
# True
# False

# %%
x = 1
y = 3
z = 5

print((x > y) or (x > z)) # False or False
print((x < y) or (x < z)) # True or True
print((x < y) or (x > z)) # False or True
# Out:
# False
# True
# True

# %%
x = 3
y = 5

print(not (x == y)) # not False
print(not (x != y)) # not True
# Out:
# True
# False

# %% [markdown]
# ## in, not in
#
# 파이썬에 존재하는 특이한 연산자이다.
#
# 리스트, 튜플, 문자열과 함께 사용되는데, 지정한 값이 이 안에 있으면 True를, 아니면 False를 반환한다.

# %%
a = [1, 2, 3, 4, 5]

print(1 in a)
print(0 in a)
# Out:
# True
# False

# %%
a = [1, 2, 3, 4, 5]

print(1 not in a)
print(0 not in a)
# Out:
# False
# True

# %%
a = 'Hello World!'

print('e' in a)
print('F' in a)
# Out:
# True
# False

# %% [markdown]
# # 다양한 조건을 판단하는 elif문

# %% [markdown]
# if와 else만을 이용해서는 다양한 조건을 판단하는 것은 가능하지만 복잡해진다.
# 따라서, 다양한 조건을 판단하기 위해서는 elif문을 활용하면 좋다.

# %%
# if와 else만을 이용한 3가지 조건 판별
# A가 B보다 크면 1을 출력하고, A가 C보다 작으면 2를 출력하고, 모두 아니라면 0을 출력해라.

a = 1
b = 2
c = 3

if a > b:
    print(1)
else:
    if a < c:
        print(2)
    else:
        print(0)
# Out:
# 2

# %%
# elif문을 활용한 3가지 조건 판별
# A가 B보다 크면 1을 출력하고, A가 C보다 작으면 2를 출력하고, 모두 아니라면 0을 출력해라.

a = 1
b = 2
c = 3

if a > b:
    print(1)
elif a < c:
    print(2)
else:
    print(0)
# Out:
# 2

# %% [markdown]
# # 조건부 표현식 (Conditional Expression)

# %%
score = 70

if score > 60:
    message = "PASS"
else:
    message = "FAIL"

print(message)
# Out:
# PASS

# %%
score = 70

message = "PASS" if score > 60 else "FAIL" # 조건부 표현식

print(message)
# Out:
# PASS

# %%
score = 50

message = "PASS" if score > 60 else "FAIL" # 조건부 표현식

print(message)
# Out:
# FAIL
