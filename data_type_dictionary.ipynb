# %% [markdown]
# # Dictionary 다루기

# %% [markdown]
# 대응 관계를 나타낼 수 있는 자료형 => 연관배열(Associative Array) or 해시(Hash)
# 파이썬에서 대응 관계를 나타낼 수 있는 자료형 => 딕셔너리(Dictionary)

# %% [markdown]
# 딕셔너리는 Key-Value가 한 쌍으로 이루어진 자료형
# 리스트와 튜플이 순차적(Sequential)으로 요소 값을 요구하는 것과 달리, 딕셔너리에서는 Key를 통해 Value를 얻는다.

# %% [markdown]
# ## 딕셔너리 선언하기

# %%
# 딕셔너리의 기본 형태
{Key1:Value1, Key2:Value2, Key3:Value3, ...}
# Out:
#   Cell In[1], line 2
#     {Key1:Value1, Key2:Value2, Key3:Value3, ...}
#                                               ^
# SyntaxError: ':' expected after dictionary key

# %%
# 딕셔네러 예
dic = {
    "name" : "청월누리",
    "phone" : "010-0000-0000",
    "since" : "230205",
    "url" : "https://dev-lunamundus.tistory.com/"
}

# %%
a = {1: "Hello"}

# %%
a = {1.0: "Hello"}

a[1.0]
# Out:
# 'Hello'

# %%
a = {'a' : [1, 2, 3]}

# %%
a = {
    'a' : {
        1 : 'Hello',
        2 : 'World'
        },
    'b' : {
        1 : 'Hi',
        2 : 'Python'
        }
    }

# %% [markdown]
# ## 딕셔너리 불러오기

# %%
dic = {
    "name" : "청월누리",
    "phone" : "010-0000-0000",
    "since" : "230417",
    "url" : "https://dev-lunamundus.tistory.com/"
}

print(f'블로그 닉네임은 : {dic["name"]}') # dictionary[key]를 통해 value 반환
print(f'블로그 번호는   : {dic["phone"]}')
print(f'블로그 개설일은 : {dic["since"]}')
print(f'블로그 주소는   : {dic["url"]}')
# Out:
# 블로그 닉네임은 : 청월누리
# 블로그 번호는   : 010-0000-0000
# 블로그 개설일은 : 230417
# 블로그 주소는   : https://dev-lunamundus.tistory.com/

# %% [markdown]
# ## 딕셔너리 쌍 추가 및 삭제하기

# %% [markdown]
# ### 쌍 추가하기

# %%
info = {} # 빈 딕셔너리 생성
info['name'] = '청월누리' # dictionary[key] = value

print(info)
# Out:
# {'name': '청월누리'}

# %%
info = {
    'name' : "청월누리"
}
info['phone'] = '010-0000-0000'

print(info)
# Out:
# {'name': '청월누리', 'phone': '010-0000-0000'}

# %% [markdown]
# ### 요소 삭제하기

# %%
info = {
    "name" : "청월누리",
    "phone" : "010-0000-0000",
    "birth" : "230205",
    "url" : "https://dev-lunamundus.tistory.com/"
}
print(info)

del info['phone']
print(info)
# Out:
# {'name': '청월누리', 'phone': '010-0000-0000', 'birth': '230205', 'url': 'https://dev-lunamundus.tistory.com/'}
# {'name': '청월누리', 'birth': '230205', 'url': 'https://dev-lunamundus.tistory.com/'}

# %% [markdown]
# ## 딕셔너리 주의점

# %% [markdown]
# 딕셔너리에서 Key는 고유한 값을 가지게 됨 => key 값을 중복해서 설정하면 하나를 제외한 나머지가 모두 사라짐

# %%
a = {1 : 'Hello', 2 : 'Python', 1 : 'Hi'}

print(a)
# Out:
# {1: 'Hi', 2: 'Python'}

# %%
info = {
    "name" : "청월누리",
    "phone" : "010-0000-0000",
    "birth" : "230205",
    "url" : "https://dev-lunamundus.tistory.com/"
}
print(info)

info["name"] = "푸른달"
print(info)
# Out:
# {'name': '청월누리', 'phone': '010-0000-0000', 'birth': '230205', 'url': 'https://dev-lunamundus.tistory.com/'}
# {'name': '푸른달', 'phone': '010-0000-0000', 'birth': '230205', 'url': 'https://dev-lunamundus.tistory.com/'}

# %%
a = {[1, 2] : 'Hello'}

print(a)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 a = {[1, 2] : 'Hello'}
#       3 print(a)
#
# TypeError: unhashable type: 'list'

# %%
a = {(1, 2) : 'Hello'}

print(a)
# Out:
# {(1, 2): 'Hello'}

# %% [markdown]
# # Dictionary Function & Method

# %% [markdown]
# ## Key & Value 리스트 얻기 : keys(), values(), items()

# %% [markdown]
# ### keys()

# %%
info = {
    "name" : "청월누리",
    "phone" : "010-0000-0000",
    "birth" : "230417",
    "url" : "https://lunamundus.tistory.com/"
}

print(info.keys()) # dictionary.keys()
print(type(info.keys()))
# Out:
# dict_keys(['name', 'phone', 'birth', 'url'])
# <class 'dict_keys'>

# %%
info = {
    "name" : "청월누리",
    "phone" : "010-0000-0000",
    "birth" : "230417",
    "url" : "https://lunamundus.tistory.com/"
}

for k in info.keys(): # 리스트처럼 사용할 수 있지만, 리스트가 아니기 때문에 리스트 고유의 함수(메소드)는 사용할 수 없음.
    print(k)
# Out:
# name
# phone
# birth
# url

# %%
info = {
    "name" : "청월누리",
    "phone" : "010-0000-0000",
    "birth" : "230417",
    "url" : "https://lunamundus.tistory.com/"
}

dic_keys = info.keys()
print(f'dic_keys : {dic_keys} / type : {type(dic_keys)}')

dic_keys = list(info.keys())
print(f'dic_keys : {dic_keys} / type : {type(dic_keys)}')
# Out:
# dic_keys : dict_keys(['name', 'phone', 'birth', 'url']) / type : <class 'dict_keys'>
# dic_keys : ['name', 'phone', 'birth', 'url'] / type : <class 'list'>

# %% [markdown]
# ### values()

# %%
info = {
    "name" : "청월누리",
    "phone" : "010-0000-0000",
    "birth" : "230417",
    "url" : "https://lunamundus.tistory.com/"
}

print(info.values()) # dict.values()
print(type(info.values()))
# Out:
# dict_values(['청월누리', '010-0000-0000', '230417', 'https://lunamundus.tistory.com/'])
# <class 'dict_values'>

# %%
info = {
    "name" : "청월누리",
    "phone" : "010-0000-0000",
    "birth" : "230417",
    "url" : "https://lunamundus.tistory.com/"
}

for v in info.values():
    print(v)
# Out:
# 청월누리
# 010-0000-0000
# 230417
# https://lunamundus.tistory.com/

# %%
info = {
    "name" : "청월누리",
    "phone" : "010-0000-0000",
    "birth" : "230417",
    "url" : "https://lunamundus.tistory.com/"
}

dic_values = info.values()
print(f'dic_keys : {dic_values}')
print(f"type : {type(dic_values)}")

print()

dic_values = list(info.values())
print(f'dic_keys : {dic_values}')
print(f"type : {type(dic_values)}")
# Out:
# dic_keys : dict_values(['청월누리', '010-0000-0000', '230417', 'https://lunamundus.tistory.com/'])
# type : <class 'dict_values'>
#
# dic_keys : ['청월누리', '010-0000-0000', '230417', 'https://lunamundus.tistory.com/']
# type : <class 'list'>

# %% [markdown]
# ### items()

# %%
info = {
    "name" : "청월누리",
    "phone" : "010-0000-0000",
    "birth" : "230417",
    "url" : "https://lunamundus.tistory.com/"
}

print(info.items())
print(type(info.items()))
# Out:
# dict_items([('name', '청월누리'), ('phone', '010-0000-0000'), ('birth', '230417'), ('url', 'https://lunamundus.tistory.com/')])
# <class 'dict_items'>

# %%
info = {
    "name" : "청월누리",
    "phone" : "010-0000-0000",
    "birth" : "230417",
    "url" : "https://lunamundus.tistory.com/"
}

for k, v in info.items():
    print(f'key : {k} / value : {v}')
# Out:
# key : name / value : 청월누리
# key : phone / value : 010-0000-0000
# key : birth / value : 230417
# key : url / value : https://lunamundus.tistory.com/

# %%
info = {
    "name" : "청월누리",
    "phone" : "010-0000-0000",
    "birth" : "230417",
    "url" : "https://lunamundus.tistory.com/"
}

dic_items = info.items()
print(f'dic_keys : {dic_items}')
print(f"type : {type(dic_items)}")

print()

dic_items = list(info.items())
print(f'dic_keys : {dic_items}')
print(f"type : {type(dic_items)}")
# Out:
# dic_keys : dict_items([('name', '청월누리'), ('phone', '010-0000-0000'), ('birth', '230417'), ('url', 'https://lunamundus.tistory.com/')])
# type : <class 'dict_items'>
#
# dic_keys : [('name', '청월누리'), ('phone', '010-0000-0000'), ('birth', '230417'), ('url', 'https://lunamundus.tistory.com/')]
# type : <class 'list'>

# %% [markdown]
# ## key로 value 얻기 : get()

# %%
info = {
    "name" : "청월누리",
    "phone" : "010-0000-0000",
    "birth" : "230417",
    "url" : "https://lunamundus.tistory.com/"
}

print(info.get('name'))
# Out:
# 청월누리

# %%
info = {
    "name" : "청월누리",
    "phone" : "010-0000-0000",
    "birth" : "230417",
    "url" : "https://lunamundus.tistory.com/"
}

print(info['name'])
# Out:
# 청월누리

# %%
info = {
    "name" : "청월누리",
    "phone" : "010-0000-0000",
    "birth" : "230417",
    "url" : "https://lunamundus.tistory.com/"
}

print(info.get('nothing'))
# Out:
# None

# %%
info = {
    "name" : "청월누리",
    "phone" : "010-0000-0000",
    "birth" : "230417",
    "url" : "https://lunamundus.tistory.com/"
}

print(info['nothing'])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[2], line 8
#       1 info = {
#       2     "name" : "청월누리",
#       3     "phone" : "010-0000-0000",
#       4     "birth" : "230417",
#       5     "url" : "https://lunamundus.tistory.com/"
#       6 }
# ----> 8 print(info['nothing'])
#
# KeyError: 'nothing'

# %% [markdown]
# ## key & value 지우기 : pop(), popitem(), clear()

# %% [markdown]
# ### pop()

# %%
info = {
    "name" : "청월누리",
    "phone" : "010-0000-0000",
    "birth" : "230417",
    "url" : "https://lunamundus.tistory.com/"
}

print(info.pop('name'))
print(info)
# Out:
# 청월누리
# {'phone': '010-0000-0000', 'birth': '230417', 'url': 'https://lunamundus.tistory.com/'}

# %%
info = {
    "name" : "청월누리",
    "phone" : "010-0000-0000",
    "birth" : "230417",
    "url" : "https://lunamundus.tistory.com/"
}

name = info.pop('name')
print(name)
# Out:
# 청월누리

# %%
info = {
    "name" : "청월누리",
    "phone" : "010-0000-0000",
    "birth" : "230417",
    "url" : "https://lunamundus.tistory.com/"
}

name = info.pop()
print(name)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[9], line 8
#       1 info = {
#       2     "name" : "청월누리",
#       3     "phone" : "010-0000-0000",
#       4     "birth" : "230417",
#       5     "url" : "https://lunamundus.tistory.com/"
#       6 }
# ----> 8 name = info.pop()
#       9 print(name)
#
# TypeError: pop expected at least 1 argument, got 0

# %% [markdown]
# ### popitem()

# %%
info = {
    "name" : "청월누리",
    "phone" : "010-0000-0000",
    "birth" : "230417",
    "url" : "https://lunamundus.tistory.com/"
}

print(info.popitem())
print(info)
# Out:
# ('url', 'https://lunamundus.tistory.com/')
# {'name': '청월누리', 'phone': '010-0000-0000', 'birth': '230417'}

# %%
info = {
    "name" : "청월누리",
    "phone" : "010-0000-0000",
    "birth" : "230417",
    "url" : "https://lunamundus.tistory.com/"
}

key_, value_ = info.popitem()
print(f"key_ : {key_}")
print(f"value_ : {value_}")
print(f"dictionary : {info}")
# Out:
# key_ : url
# value_ : https://lunamundus.tistory.com/
# dictionary : {'name': '청월누리', 'phone': '010-0000-0000', 'birth': '230417'}

# %%
info = {
    "name" : "청월누리",
    "phone" : "010-0000-0000",
    "birth" : "230417",
    "url" : "https://lunamundus.tistory.com/"
}

dict_last = info.popitem()
print(type(dict_last))
print(dict_last)
# Out:
# <class 'tuple'>
# ('url', 'https://dev-lunamundus.tistory.com/')

# %%
info = {
    "name" : "청월누리",
    "phone" : "010-0000-0000",
    "birth" : "230417",
    "url" : "https://lunamundus.tistory.com/"
}

print(info.popitem('name'))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[10], line 8
#       1 info = {
#       2     "name" : "청월누리",
#       3     "phone" : "010-0000-0000",
#       4     "birth" : "230417",
#       5     "url" : "https://lunamundus.tistory.com/"
#       6 }
# ----> 8 print(info.popitem('name'))
#
# TypeError: dict.popitem() takes no arguments (1 given)

# %% [markdown]
# ### clear()

# %%
info = {
    "name" : "청월누리",
    "phone" : "010-0000-0000",
    "birth" : "230417",
    "url" : "https://lunamundus.tistory.com/"
}

info.clear()
print(info)
# Out:
# {}

# %% [markdown]
# ## 값 수정 및 추가하기 : setdefault(), update()

# %% [markdown]
# ### setdefault()

# %%
info = {
    "name" : "청월누리",
    "phone" : "010-0000-0000",
    "birth" : "230417",
    "url" : "https://lunamundus.tistory.com/"
}

info.setdefault('phone', '010-9999-9999') # key가 있는 경우, 아무런 변화 없음

print(info)
# Out:
# {'name': '청월누리', 'phone': '010-0000-0000', 'birth': '230417', 'url': 'https://lunamundus.tistory.com/'}

# %%
info = {
    "name" : "청월누리",
    "phone" : "010-0000-0000",
    "birth" : "230417",
    "url" : "https://lunamundus.tistory.com/"
}

info.setdefault('email', 'dev-lunamundus@example.com') # key가 없는 경우 새로운 key-value 쌍이 추가됨

print(info)
# Out:
# {'name': '청월누리', 'phone': '010-0000-0000', 'birth': '230417', 'url': 'https://lunamundus.tistory.com/', 'email': 'dev-lunamundus@example.com'}

# %% [markdown]
# ### update()

# %%
info = {
    "name" : "청월누리",
    "phone" : "010-0000-0000",
    "birth" : "230417",
    "url" : "https://lunamundus.tistory.com/"
}

info.update({"phone" : "010-9999-9999"})

print(info)
# Out:
# {'name': '청월누리', 'phone': '010-9999-9999', 'birth': '230417', 'url': 'https://lunamundus.tistory.com/'}

# %%
info = {
    "name" : "청월누리",
    "phone" : "010-0000-0000",
    "birth" : "230417",
    "url" : "https://lunamundus.tistory.com/"
}

info.update({"email" : "dev-lunamundus@example.com"})

print(info)
# Out:
# {'name': '청월누리', 'phone': '010-0000-0000', 'birth': '230417', 'url': 'https://lunamundus.tistory.com/', 'email': 'dev-lunamundus@example.com'}
